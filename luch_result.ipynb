# %%
from selenium.webdriver import Chrome
from selenium import webdriver 
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.select import Select
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains
import pandas as pd

# %%
options = webdriver.ChromeOptions()
prefs = {"download.default_directory": "C:/Users/ADMIN/Downloads/DownloadbotIsr"}
options.add_experimental_option("prefs",prefs)
url = "https://pvp.giustizia.it/pvp/it/homepage.page"
driver_path = "C:/Users/ADMIN/pvpBot/chromedriver.exe"
browser = Chrome(executable_path = driver_path, chrome_options=options)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1956\2291475047.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = Chrome(executable_path = driver_path, chrome_options=options)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1956\2291475047.py:6: DeprecationWarning: use options instead of chrome_options
#   browser = Chrome(executable_path = driver_path, chrome_options=options)

# %%
unique_ = pd.read_csv("data/Vinicio/Pioltello.txt", sep=" ", header=None)
unique_["No"] = 0
unique_.shape
# Out:
# (2, 2)

# %%
unique_
# Out:
#                                                    0  No
# 0  https://pvp.giustizia.it/pvp/it/dettaglio_annu...   0
# 1  https://pvp.giustizia.it/pvp/it/dettaglio_annu...   0

# %%
from time import sleep
action = ActionChains(browser)
data_docs = {}

for url_i in list(unique_[0]):
    str_compose = f'''
    window.open("{url_i}");
    '''
    #window.open("{url_i}","_blank");

    browser.execute_script(str_compose)
    print(browser.current_url)
    sleep(2)
# Out:
# data:,
# data:,

# %%
import os
path=f"{os.getcwd()}\\data\\marco"
isFile = os.path.isdir(path) 
print(isFile)
# Out:
# True

# %% [markdown]
# ## Prova di Scarica aste:

# %%
from scrapingSearch import astaSearch
LOC_FUNCTION = ["Sesto San Giovanni (MI)","Milano (MI)", "Paderno (MI)","Bonola (MI)","Cormano (MI)", "Donato (MI)", "Bresso (MI)","Baranzate (MI)", "Cinisello (MI)", "Paderno (MI)", "Pioltello"]
#LOC_FUNCTION = ["Milano (MI)", "Baranzate (MI)"]
MESE_ASTA = ["12","01","02","03"]
PREZZO_RANGE = ["20.000", "50.000"]
for i in LOC_FUNCTION:
    astaSearch(i,MESE_ASTA=MESE_ASTA,PREZZO_RANGE=PREZZO_RANGE, cliente="Vinicio")
# Out:
# Numero di date valide per possibili aste: 0
# Numero totale di aste effetivamente valide : 0
# I migliori annunci trovati (0,) per l'intervallo di prezzo ['20.000', '50.000'] nella zona di Sesto San Giovanni (MI)
# Numero di date valide per possibili aste: 8
# Numero totale di aste effetivamente valide : 7
# I migliori annunci trovati (4,) per l'intervallo di prezzo ['20.000', '50.000'] nella zona di Milano (MI)
# Numero di date valide per possibili aste: 0
# Numero totale di aste effetivamente valide : 0
# I migliori annunci trovati (0,) per l'intervallo di prezzo ['20.000', '50.000'] nella zona di Paderno (MI)
# Numero di date valide per possibili aste: 0
# Numero totale di aste effetivamente valide : 0
# I migliori annunci trovati (0,) per l'intervallo di prezzo ['20.000', '50.000'] nella zona di Bonola (MI)
# Numero di date valide per possibili aste: 0
# Numero totale di aste effetivamente valide : 0
# I migliori annunci trovati (0,) per l'intervallo di prezzo ['20.000', '50.000'] nella zona di Cormano (MI)
# Numero di date valide per possibili aste: 0
# Numero totale di aste effetivamente valide : 0
# I migliori annunci trovati (0,) per l'intervallo di prezzo ['20.000', '50.000'] nella zona di Donato (MI)
# Numero di date valide per possibili aste: 0
# Numero totale di aste effetivamente valide : 0
# I migliori annunci trovati (0,) per l'intervallo di prezzo ['20.000', '50.000'] nella zona di Bresso (MI)
# Numero di date valide per possibili aste: 0
# Numero totale di aste effetivamente valide : 0
# I migliori annunci trovati (0,) per l'intervallo di prezzo ['20.000', '50.000'] nella zona di Baranzate (MI)
# Numero di date valide per possibili aste: 0
# Numero totale di aste effetivamente valide : 0
# I migliori annunci trovati (0,) per l'intervallo di prezzo ['20.000', '50.000'] nella zona di Cinisello (MI)
# Numero di date valide per possibili aste: 0
# Numero totale di aste effetivamente valide : 0
# I migliori annunci trovati (0,) per l'intervallo di prezzo ['20.000', '50.000'] nella zona di Paderno (MI)
# Numero di date valide per possibili aste: 9
# Numero totale di aste effetivamente valide : 9
# I migliori annunci trovati (2,) per l'intervallo di prezzo ['20.000', '50.000'] nella zona di Pioltello
