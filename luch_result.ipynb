# %%
from selenium.webdriver import Chrome
from selenium import webdriver 
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.select import Select
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains
import pandas as pd
from time import sleep
# Out:
# C:\Users\ADMIN\Miniconda3\envs\envP9\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\ADMIN\Miniconda3\envs\envP9\lib\site-packages\numpy\.libs\libopenblas.gk7gx5keq4f6uyo3p26ulgbqyhgqo7j4.gfortran-win_amd64.dll
# C:\Users\ADMIN\Miniconda3\envs\envP9\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
options = webdriver.ChromeOptions()
prefs = {"download.default_directory": "C:/Users/ADMIN/Downloads/DownloadbotIsr"}
options.add_experimental_option("prefs",prefs)
url = "https://pvp.giustizia.it/pvp/it/homepage.page"
driver_path = "C:/Users/ADMIN/botIsra/chromedriver.exe"
browser = Chrome(executable_path = driver_path, chrome_options=options)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_19852\4107184763.py:6: DeprecationWarning: use options instead of chrome_options
#   browser = Chrome(executable_path = driver_path, chrome_options=options)

# %%
import pandas as pd
unique_ = pd.read_csv("data/MediaCom/Milano (MI).html", sep=" ", header=None)
unique_["No"] = 0
unique_.shape
# Out:
# (20, 2)

# %%
def browser_loop(url_):
    return browser.get(url_)

# %%
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
for url_i in list(unique_[0][:6]):
    browser_loop(url_i)
    sleep(2)
    browser.find_element_by_tag_name('body').send_keys(Keys.CONTROL + 'w')
    print(browser.current_url)
# Out:
# https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6116991&elementiPerPagina=50&ricerca_libera=Milano+%28MI%29&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=80.000&procedura=&raggio=25&prezzo_a=120.000&lat=&tribunale=
# https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6204326&elementiPerPagina=50&ricerca_libera=Milano+%28MI%29&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=80.000&procedura=&raggio=25&prezzo_a=120.000&lat=&tribunale=
# https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6293044&elementiPerPagina=50&ricerca_libera=Milano+%28MI%29&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=80.000&procedura=&raggio=25&prezzo_a=120.000&lat=&tribunale=
# https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6303157&elementiPerPagina=50&ricerca_libera=Milano+%28MI%29&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=80.000&procedura=&raggio=25&prezzo_a=120.000&lat=&tribunale=
# https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6309168&elementiPerPagina=50&ricerca_libera=Milano+%28MI%29&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=80.000&procedura=&raggio=25&prezzo_a=120.000&lat=&tribunale=
# https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6315718&elementiPerPagina=50&ricerca_libera=Milano+%28MI%29&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=80.000&procedura=&raggio=25&prezzo_a=120.000&lat=&tribunale=

# %%
from time import sleep
action = ActionChains(browser)
data_docs = {}

for url_i in list(unique_[0][:]):
    str_compose = f'''
    window.open("{url_i}");
    '''
    #window.open("{url_i}","_blank");

    browser.execute_script(str_compose)
    print(browser.current_url)
    sleep(2)
# Out:
# https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6315718&elementiPerPagina=50&ricerca_libera=Milano+%28MI%29&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=80.000&procedura=&raggio=25&prezzo_a=120.000&lat=&tribunale=
# https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6315718&elementiPerPagina=50&ricerca_libera=Milano+%28MI%29&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=80.000&procedura=&raggio=25&prezzo_a=120.000&lat=&tribunale=
# https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6315718&elementiPerPagina=50&ricerca_libera=Milano+%28MI%29&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=80.000&procedura=&raggio=25&prezzo_a=120.000&lat=&tribunale=
# https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6315718&elementiPerPagina=50&ricerca_libera=Milano+%28MI%29&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=80.000&procedura=&raggio=25&prezzo_a=120.000&lat=&tribunale=
# https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6315718&elementiPerPagina=50&ricerca_libera=Milano+%28MI%29&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=80.000&procedura=&raggio=25&prezzo_a=120.000&lat=&tribunale=
# https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6315718&elementiPerPagina=50&ricerca_libera=Milano+%28MI%29&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=80.000&procedura=&raggio=25&prezzo_a=120.000&lat=&tribunale=
# https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6315718&elementiPerPagina=50&ricerca_libera=Milano+%28MI%29&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=80.000&procedura=&raggio=25&prezzo_a=120.000&lat=&tribunale=
# https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6315718&elementiPerPagina=50&ricerca_libera=Milano+%28MI%29&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=80.000&procedura=&raggio=25&prezzo_a=120.000&lat=&tribunale=
# https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6315718&elementiPerPagina=50&ricerca_libera=Milano+%28MI%29&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=80.000&procedura=&raggio=25&prezzo_a=120.000&lat=&tribunale=
# https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6315718&elementiPerPagina=50&ricerca_libera=Milano+%28MI%29&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=80.000&procedura=&raggio=25&prezzo_a=120.000&lat=&tribunale=
# https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6315718&elementiPerPagina=50&ricerca_libera=Milano+%28MI%29&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=80.000&procedura=&raggio=25&prezzo_a=120.000&lat=&tribunale=
# https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6315718&elementiPerPagina=50&ricerca_libera=Milano+%28MI%29&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=80.000&procedura=&raggio=25&prezzo_a=120.000&lat=&tribunale=
# https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6315718&elementiPerPagina=50&ricerca_libera=Milano+%28MI%29&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=80.000&procedura=&raggio=25&prezzo_a=120.000&lat=&tribunale=
# https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6315718&elementiPerPagina=50&ricerca_libera=Milano+%28MI%29&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=80.000&procedura=&raggio=25&prezzo_a=120.000&lat=&tribunale=

# %%
import os
path=f"{os.getcwd()}\\data\\marco"
isFile = os.path.isdir(path) 
print(isFile)
# Out:
# True

# %% [markdown]
# ## Prova di Scarica aste:

# %%
from scrapingSearch import astaSearch
LOC_FUNCTION = ["Sesto San Giovanni (MI)","Milano (MI)", "Paderno (MI)","Bonola (MI)","Cormano (MI)", "Donato (MI)", "Bresso (MI)","Baranzate (MI)", "Cinisello (MI)", "Paderno (MI)", "Pioltello"]
#LOC_FUNCTION = ["Monza (MB)", "Lissone (MB)", "Muggiò (MB)", "Cinisello Balsamo (MI)", "Concorezzo (MB)", "Desio (MB)"]
#LOC_FUNCTION = ["Milano (MI)", "Bovisa (MI)", "Certosa (MI)", "Via varesina (MI)", "Quarto Oggiaro (MI)"]
#LOC_FUNCTION = ["Vimercate (MB)"]
MESE_ASTA = ["02","03","04","05"]
PREZZO_RANGE = ["20.000", "90.000"]
for i in LOC_FUNCTION:
    astaSearch(i,MESE_ASTA=MESE_ASTA,PREZZO_RANGE=PREZZO_RANGE, cliente="Marco")
# Out:
# Numero di date valide per possibili aste: 14
# Numero totale di aste effetivamente valide : 3
# I migliori annunci trovati (3,) per l'intervallo di prezzo ['20.000', '90.000'] nella zona di Vimercate (MB)

# %%
via mauro macchi 26
