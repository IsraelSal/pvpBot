# %%
from selenium.webdriver import Chrome
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.select import Select
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains
from time import sleep
from selenium.webdriver.common.by import By

# %%
def browser_loop(url_):
    return browser.get(url_)

# %% [markdown]
# Qui lanciamo il BROWSER per la ricerca

# %%
url = "https://www.linkedin.com/login/it"
driver_path = "C:/Users/ADMIN/botIsra/chromedriver.exe"
browser = Chrome(executable_path = driver_path)
browser.get(url)

# %% [markdown]
# Chiudiamo l'aviso di emergenza

# %%
search_id = "username"
search_id_psw = "password"
#class_b = "btn-primary.bottoni-chiusura"
element_search = browser.find_element_by_id(search_id)
element_search.send_keys("giorgio.defilippo@tech-engineering.it")

#element_search.send_keys("i.salgadobecerra@campus.unimib.it")
element_search_psw = browser.find_element_by_id(search_id_psw)
element_search_psw.send_keys("giorgio77")

#element_search_psw.send_keys("Israel22")
element_search.submit()

# %%
browser_sear = browser.current_url
browser_sear
# Out:
# 'https://www.linkedin.com/feed/'

# %% [markdown]
# Click sulla ricerca estesa

# %%
def ricerca_candidato(search_bar):
    browser.get(browser_sear)
    search_ = "search-global-typeahead__input.always-show-placeholder"
    rese = browser.find_element_by_class_name(search_)
    rese.clear()
    rese.send_keys(search_bar)
    rese.send_keys(Keys.ENTER)
    #rese.submit()

# %%
ricerca_candidato("power operator")

# %%
def filter_by_person():
    cl_persone = "artdeco-pill.artdeco-pill--slate.artdeco-pill--choice.artdeco-pill--2.search-reusables__filter-pill-button.search-reusables__filter-pill-button"
    click_per = browser.find_element_by_class_name(cl_persone)
    click_per.click()

# %%
filter_by_person()

# %%
cl_persone = "artdeco-pill.artdeco-pill--slate.artdeco-pill--choice.artdeco-pill--2.search-reusables__filter-pill-button.search-reusables__filter-pill-button"
click_per = browser.find_element_by_class_name(cl_persone)
click_per.click()

# %%
def lunch_location(xid_lo,xid_inp,ok_button,location_search):
    click_loc = browser.find_element_by_xpath(xid_lo)
    click_loc.click()
    sleep(2)
    click_inp = browser.find_element_by_xpath(xid_inp)
    click_inp.clear()
    click_inp.send_keys(location_search)
    sleep(3)
    click_inp.send_keys(Keys.DOWN)
    sleep(3)
    click_inp.send_keys(Keys.ENTER)
    sleep(1)
    clic_mostr = browser.find_element_by_xpath(ok_button)
    clic_mostr.click()

def filter_role_location(role_search,location_search):
    ricerca_candidato(role_search)
    sleep(3)
    filter_by_person()
    sleep(2)
    button_loc = "/section/div/nav/div/ul/li[4]/div/span/button"
    button_inp = "/section/div/nav/div/ul/li[4]/div/div/div/div[1]/div/form/fieldset/div[1]/div/div/input"
    button_ok_search ="/section/div/nav/div/ul/li[4]/div/div/div/div[1]/div/form/fieldset/div[2]/button[2]/span"
    #html/body/div[6]/div[3]/div/div[2]/section/div/nav/div/ul/li[4]/div/span/button
    #/html/body/div[6]/div[3]/div/div[2]/section/div/nav/div/ul/li[4]/div/span/button
    #/html/body/div[6]/div[3]/div/div[2]/section/div/nav/div/ul/li[4]/div/span/button
    #/html/body/div[6]/div[3]/div/div[2]/section/div/nav/div/ul/li[4]/div/div/div/div[1]/div/form/fieldset/div[2]/button[2]/span
    #"/html/body/div[7]/div[3]/div/div[2]/section/div/nav/div/ul/li[4]/div/div/div/div[1]/div/form/fieldset/div[2]/button[2]/span"
    
    try:
        part1 = "/html/body/div[6]/div[3]/div/div[2]"
        loc_ser = part1+button_loc
        loc_inp = part1+button_inp
        loc_ok = part1+button_ok_search
        lunch_location(loc_ser, loc_inp, loc_ok, location_search)
    except:
        pass
    try:
        part2 = "/html/body/div[7]/div[3]/div/div[2]"
        loc_ser = part2+button_loc
        loc_inp = part2+button_inp
        loc_ok = part2+button_ok_search
        lunch_location(loc_ser, loc_inp, loc_ok, location_search)
    except:
        pass

# %%
filter_role_location("Oss","Genova")

# %%
import numpy as np
valid_path = "https://www.linkedin.com/in/"
div_link = browser.find_elements(By.TAG_NAME, "a")
links = [d.get_attribute("href") for d in div_link]
valid_links = [d for d in links if d != None]

unique_ = np.unique(np.array(valid_links))
unique_.shape
# Out:
# (33,)

# %%
u = 30
unique_[u],len(unique_[u])
# Out:
# ('https://www.linkedin.com/search/results/all/?keywords=telecommunications&origin=RELATED_SEARCH_FROM_SRP',
#  103)

# %%
# loc_ser='//*[@id="artdeco-hoverable-artdeco-gen-62"]/div[1]/div/form/fieldset/div[1]/div/div/input'
# //*[@id="artdeco-hoverable-artdeco-gen-43"]/div[1]/div/form/fieldset/div[1]/div/div/input
# //*[@id="artdeco-hoverable-artdeco-gen-48"]/div[1]/div/form/fieldset/div[1]/div/div/input
#loc_ser = '//*[@id="ember2923"]/button'
loc_ser = '/html/body/div[7]/div[3]/div/div[2]/section/div/nav/div/ul/li[4]/div/span/button'
loc_inp = "/html/body/div[7]/div[3]/div/div[2]/section/div/nav/div/ul/li[4]/div/div/div/div[1]/div/form/fieldset/div[1]/div/div/input"
click_loc = browser.find_element_by_xpath(loc_ser)
click_loc.click()
sleep(2)
click_inp = browser.find_element_by_xpath(loc_inp)
click_inp.clear()

click_inp.send_keys("Rome")
sleep(3)
click_inp.send_keys(Keys.DOWN)
sleep(3)
click_inp.send_keys(Keys.ENTER)
sleep(1)
ok_loc = "/html/body/div[7]/div[3]/div/div[2]/section/div/nav/div/ul/li[4]/div/div/div/div[1]/div/form/fieldset/div[2]/button[2]/span"
clic_mostr = browser.find_element_by_xpath(ok_loc)
clic_mostr.click()

# %%
g = """"
Egregio Sig/Ing. buongiorno,
per conto del nostro Cliente Multinazionale siamo alla ricerca di un Supervisore Meccanico.
Se di suo interesse la prego di inviarmi il suo CV aggiornato.
Rimango a disposizione per i dettagli.
Cordiali saluti,
cristian.ioan@tech-engineering.it 
"""

# %%
local = "artdeco-pill.artdeco-pill--slate.artdeco-pill--choice.artdeco-pill--2.search-reusables__filter-pill-button"
click_loc = browser.find_element_by_class_name(local)
click_loc.send_keys("italia")

# %% [markdown]
# Ricerchiamo per zona geografica

# %%
# Qui bisogna mettere un wait()
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
input_id = "IDricercalibera1"
wait = WebDriverWait(browser, 10)
element = wait.until(EC.element_to_be_clickable((By.ID, input_id)))
search = browser.find_element_by_id(input_id)
search.clear()
search.send_keys("via galarate")
search.submit()

# %% [markdown]
# Ordinare i campi

# %%
ordina = "astaMinima"
df = Select(browser.find_element_by_id(ordina))
df.select_by_visible_text("Data vendita ▼")

# %% [markdown]
# Filtra per prezzo

# %%
prezzo_id ="prezzo-da"
prezzo_id_="prezzo-a"
p_da = browser.find_element_by_id(prezzo_id)
p_a = browser.find_element_by_id(prezzo_id_)

p_da.clear()
p_a.clear()

p_da.send_keys("30.000")
p_a.send_keys("60.000")

p_a.submit()

# %% [markdown]
# Scelta numero di annunci per pagina

# %%
pg_id = "select-paginazione"
pg_ = Select(browser.find_element_by_id(pg_id))
pg_.select_by_visible_text("50")

# %% [markdown]
# Risultati in forma di lista

# %%
list_ele = "glyphicon.glyphicon-list.hidden-xs"
clic_list = browser.find_element_by_class_name(list_ele)
clic_list.click()

# %% [markdown]
# download i link validi

# %%
import numpy as np

div_link = browser.find_elements(By.TAG_NAME, "a")
links = [d.get_attribute("href") for d in div_link]
valid_links = [d for d in links if d != None]
link_asta = [s for s in valid_links if s.find("contentId")!=-1]
unique_ = np.unique(np.array(link_asta))
unique_.shape
# Out:
# (50,)

# %%
unique_
# Out:
# array(['https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT5981906&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6246573&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6264864&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6264869&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6283699&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6293118&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6299737&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6300393&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6309999&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6314424&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6316075&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6317469&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6317555&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6317611&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6320490&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6325294&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6326533&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6327402&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6334057&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6334161&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6335504&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6335532&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6337306&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6337876&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6340964&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6347751&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6347889&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6350840&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6357974&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6362533&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6362644&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6362689&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6362715&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6362722&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6362770&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6362790&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6367087&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6367516&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6369932&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6372694&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6373958&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6376192&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6377907&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6379323&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6379493&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6381977&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6383141&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6383295&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=',
#        'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6383371&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale='],
#       dtype='<U367')

# %% [markdown]
# i 7 appartamenti per le prossime aste

# %%
last7 = unique_[-7:]
for url_i in last7:
    browser_loop(url_i)

# %% [markdown]
# Adesso ci salviamo il link della pagina della ricerca

# %%
print(browser.current_url)
# Out:
# https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?ordinamento=data_vendita_decre&anno=&disponibilita=&lng=&searchresults=true&categoria=&indirizzo=&contentId=LTT6383371&elementiPerPagina=50&ricerca_libera=via+galarate&ordine_localita=a_z&idInserzione=&tipo_bene=immobili&geo=raggio&view=list&prezzo_da=30.000&procedura=&raggio=25&prezzo_a=60.000&lat=&tribunale=

# %%
dd = browser.find_element_by_tag_name('body').screenshot_as_png
Image.open(BytesIO(dd))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31060\3180123298.py in <module>
#       1 dd = browser.find_element_by_tag_name('body').screenshot_as_png
# ----> 2 Image.open(BytesIO(dd))
#
# NameError: name 'Image' is not defined

# %%
import requests
image = requests.get(browser.current_url).headers
image
# Out:
# {'Date': 'Thu, 27 Jan 2022 06:31:31 GMT', 'Server': 'Apache', 'Strict-Transport-Security': 'max-age=63072000; includeSubdomains;', 'Content-Type': 'text/html;charset=UTF-8', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'Cache-Control': 'private, no-cache, no-store, proxy-revalidate, no-transform', 'Expires': 'Thu, 27 Jan 2022 06:31:31 GMT', 'Set-Cookie': 'JSESSIONID=MC3DJbjqODNHegOT6-N9bnyu; Path=/pvp; Secure;HttpOnly;Secure, ROUTEIDPVP=.14; path=/pvp; HTTPOnly; Secure', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'Pragma': 'no-cache', 'X-Frame-Options': 'DENY', 'Content-Length': '7368', 'Keep-Alive': 'timeout=5, max=100', 'Connection': 'Keep-Alive'}

# %%
from urllib.request import urlopen
html = urlopen(browser.current_url)
page_content = str(html.read())

with open('page_content.html', 'w') as fid:
    fid.write(page_content)

# %%
page_content
# Out:
# 'b\'\\r\\n\\r\\n\\r\\n\\r\\n<!DOCTYPE html >\\r\\n<html lang="it">\\r\\n\\r\\n<head>\\r\\n\\t<meta charset="utf-8">\\r\\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\\r\\n    <meta name="viewport" content="width=device-width, initial-scale=1">\\r\\n    <!-- The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags -->\\r\\n    <title>Portale Vendite Pubbliche - LOTTO UNICO</title>\\r\\n    <link href="/pvp-resources/static/css/style.css" rel="stylesheet">\\r\\n\\r\\n    <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->\\r\\n    <!-- WARNING: Respond.js doesn\\\'t work if you view the page via file:// -->\\r\\n    <!--[if lt IE 9]>\\r\\n      <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>\\r\\n      <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>\\r\\n    <![endif]-->\\r\\n    <link href=\\\'https://fonts.googleapis.com/css?family=Montserrat:400,700\\\' rel=\\\'stylesheet\\\' type=\\\'text/css\\\'>\\r\\n\\t<link href=\\\'/pvp-resources/static/lib/bootstrap-slider/bootstrap-slider.min.css\\\' rel=\\\'stylesheet\\\' type=\\\'text/css\\\'>\\r\\n    <link rel="stylesheet" href="/pvp-resources/static/lib/bootstrap-carousel-modal/bootstrap-modal-carousel.min.css">\\r\\n\\t<link href="/pvp-resources/static/css/styleEdited.css" rel="stylesheet">\\r\\n\\t<link href="https://ajax.googleapis.com/ajax/libs/jqueryui/1.8.9/themes/base/jquery-ui.css" rel="stylesheet" type="text/css"/>\\r\\n\\t<script src="/pvp-resources/static/lib/jquery/jquery-1.12.3.min.js"></script>\\r\\n\\t<script type="text/javascript" src="https://maps.googleapis.com/maps/api/js?key=AIzaSyDJehAWu3_QKEtQ980hlokDXnfFsMmB8Ow&libraries=places"></script>\\r\\n</head>\\r\\n\\r\\n\\r\\n\\t<body>\\r\\n\\t\\t\\r\\n\\r\\n\\r\\n<!-- Modal -->\\r\\n    <div class="modal modal-default fade" id="modalInformativa" role="dialog">\\r\\n        <div class="modal-dialog">\\r\\n\\r\\n            <!-- Modal content-->\\r\\n            <div class="modal-content">\\r\\n                <div class="modal-header">\\r\\n                    <button type="button" class="close bottoni-chiusura" data-dismiss="modal">&times;</button>\\r\\n                    <h4 class="modal-title">AVVERTENZA</h4>\\r\\n                </div>\\r\\n                <div class="modal-body">\\r\\n                    Si informa che l\\xe2\\x80\\x99interoperabilit\\xc3\\xa0 con i siti privati per la pubblicit\\xc3\\xa0 e per la vendita telematica non potr\\xc3\\xa0 avvenire fino a quando essi non procederanno ad accreditarsi sul Portale dopo aver reso conformi i propri siti alle specifiche tecniche pubblicate.\\r\\n\\r\\nAssistenza\\r\\n\\r\\nPer la corretta autenticazione e pubblicazione degli avvisi di vendita e per il corretto invio dell\\xe2\\x80\\x99offerta nonch\\xc3\\xa9 per l\\xe2\\x80\\x99interoperabilit\\xc3\\xa0 con i siti di pubblicit\\xc3\\xa0/gestori della vendita telematica, sono disponibili i manuali utente nelle sezione \\xe2\\x80\\x9cFAQ\\xe2\\x80\\x9d del Portale.\\r\\n\\r\\nPer problemi di accesso/autenticazione nell\\xe2\\x80\\x99area riservata del Portale e per difficolt\\xc3\\xa0 tecniche di interoperabilit\\xc3\\xa0 con il Portale riscontrate dai siti di pubblicit\\xc3\\xa0/gestori delle vendite si pu\\xc3\\xb2 chiamare il call center al numero 800236160 (da luned\\xc3\\xac al venerd\\xc3\\xac dalle ore 8 alle ore 18) o scrivere ad assistenzatecnicapvp.dgsia@giustizia.it.\\r\\nPer ulteriori problemi riscontrati in fase di pubblicazione degli avvisi di vendita, una volta effettuato l\\xe2\\x80\\x99accesso al Portale, si pu\\xc3\\xb2 cliccare sulla voce \\xe2\\x80\\x9cRichiedi assistenza\\xe2\\x80\\x9d del menu a sinistra.\\r\\nSi precisa che il supporto offerto \\xc3\\xa8 strettamente correlato a problematiche tecniche e che per ogni chiarimento relativo ai beni in vendita occorre fare riferimento al soggetto indicato nell\\xe2\\x80\\x99avviso di  ...
